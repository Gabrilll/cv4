# %%
# !git clone https://github.com/davidsandberg/facenet.git
# Out:
# Cloning into 'facenet'...
# remote: Enumerating objects: 3149, done.
# remote: Total 3149 (delta 0), reused 0 (delta 0), pack-reused 3149
# Receiving objects: 100% (3149/3149), 2.92 MiB | 664.00 KiB/s, done.
# Resolving deltas: 100% (2234/2234), done.

# %%
import os

# %%
os.environ['PYTHONPATH']='facenet/src'+':facenet/src/align'
print(os.environ['PYTHONPATH'])
# Out:
# facenet/src:facenet/src/align

# %%
# !unzip /mnt/hw4/cv21b.programming04.zip
# Out:
# Archive:  /mnt/hw4/cv21b.programming04.zip
# replace eval.py? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
# !pip install numpy==1.16.1
import numpy as np
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# ...
#      |████████████████████████████████| 17.3MB 5.5MB/s eta 0:00:01
# ...
#   Found existing installation: numpy 1.18.1
#     Uninstalling numpy-1.18.1:
#       Successfully uninstalled numpy-1.18.1
# ...

# %%
# !pip install scipy==1.2.1
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# ...
#      |████████████████████████████████| 24.8MB 6.4MB/s eta 0:00:01     |███████████████████████▌        | 18.2MB 6.0MB/s eta 0:00:02
# ...
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ...

# %%
# !pip install tensorflow==1.15
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# ...
#      |████████████████████████████████| 412.3MB 4.5MB/s eta 0:00:01    |█▋                              | 20.7MB 6.2MB/s eta 0:01:03     |███████▉                        | 101.6MB 4.4MB/s eta 0:01:12     |███████████████████▊            | 254.2MB 6.5MB/s eta 0:00:25     |███████████████████████         | 296.3MB 3.9MB/s eta 0:00:30     |███████████████████████▍        | 301.7MB 2.1MB/s eta 0:00:52
# ...
#      |████████████████████████████████| 512kB 6.9MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.8MB 3.3MB/s eta 0:00:01
# ...
#   Found existing installation: tensorflow-estimator 2.0.0
#     Uninstalling tensorflow-estimator-2.0.0:
#       Successfully uninstalled tensorflow-estimator-2.0.0
#   Found existing installation: tensorboard 2.0.0
#     Uninstalling tensorboard-2.0.0:
#       Successfully uninstalled tensorboard-2.0.0
#   Found existing installation: tensorflow 2.0.0
#     Uninstalling tensorflow-2.0.0:
# ...

# %%
# !python facenet/src/align/align_dataset_mtcnn.py train train_mtcnn --image_size 182 --margin 44

# %%
# !pip install tensorflow-gpu==1.15
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# ...
#      |████████████████████████████████| 411.5MB 4.6MB/s eta 0:00:01     |████████                        | 103.3MB 2.8MB/s eta 0:01:50     |████████▊                       | 112.0MB 5.1MB/s eta 0:01:00     |██████████████████████▉         | 294.2MB 4.0MB/s eta 0:00:30
# ...

# %%
# !python facenet/src/train_softmax.py --data_dir train_mtcnn --epoch_size 35 --max_nrof_epochs 10
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Model directory: /root/models/facenet/20210529-020340
# Log directory: /root/logs/facenet/20210529-020340
# WARNING:tensorflow:From facenet/src/train_softmax.py:98: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:From facenet/src/train_softmax.py:111: range_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# !python facenet/src/align/align_dataset_mtcnn.py test test_mtcnn --image_size 182 --margin 44

# %%
# !rm -r val_mtcnn/

# %%
# !cp -r /root/models/facenet /mnt/hw4/models
